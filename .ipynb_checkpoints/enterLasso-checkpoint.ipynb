# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import Ridge, RidgeCV, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()
X, y = data.data, data.target

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df['MedHouseVal'] = data.target
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# We'll do OLS leaving the multicolinear variables
# Then we'll do OLS removing the multicolinear variables using Correlation Matrix and VIF 

# Then we'll compare both 

# Then we'll do stepwise regression with R2 and AIC
# Do stepwise with CV 

# compare both
# compare everything

# Then we'll do lasso and Ridge
