# %%
import pandas as pd

# %%
df = pd.read_csv("data/Housing.csv")

# %%
df.shape
# Out:
# (545, 13)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
pd.get_dummies(df["furnishingstatus"]).head()
# Out:
#    furnished  semi-furnished  unfurnished
# 0       True           False        False
# 1       True           False        False
# 2      False            True        False
# 3       True           False        False
# 4       True           False        False

# %%
pd.get_dummies(df["furnishingstatus"], drop_first=True).head()
# Out:
#    semi-furnished  unfurnished
# 0           False        False
# 1           False        False
# 2            True        False
# 3           False        False
# 4           False        False

# %%
predictors = ["area", "furnishingstatus", "basement", "bedrooms"]
X = pd.get_dummies(df[predictors], drop_first=True)
X.head()
# Out:
#    area  bedrooms  furnishingstatus_semi-furnished  \
# 0  7420         4                            False
# 1  8960         4                            False
# 2  9960         3                             True
# 3  7500         4                            False
# 4  7420         4                            False
#
#    furnishingstatus_unfurnished  basement_yes
# 0                         False         False
# 1                         False         False
# 2                         False          True
# 3                         False          True
# 4                         False          True
